# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
data = pd.read_csv ('https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv')
data.head(10)
data.isnull == True
sns.set_style('whitegrid')
sns.scatterplot(y= data['Scores'], x= data['Hours'])
plot.title('Hours Vs Percentage',size=15)
plot.ylabel('Percentage Score', size=10)
plot.xlabel('Hours Studied', size=10)
plot.show()
sns.regplot(x= data['Hours'], y= data['Scores'])
plot.title('Regression Plot',size=15)
plot.ylabel('Percentage Score', size=10)
plot.xlabel('Hours Studied', size=10)
plot.show()
print(data.corr())
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print("TRAINING COMPLETE")
y_pred = regressor.predict(X_val)
prediction = pd.DataFrame({'Hours': [i[0] for i in X_val], 'Predicted Percentage': [k for k in pred_y]})
prediction
compare_scores = pd.DataFrame({'Actual Percentage': y_val, 'Predicted Percentage': pred_y})
compare_scores
plot.scatter(x=X_val, y=y_val, color='red')
plot.plot(X_val, y_pred, color='Black')
plot.title('Actual vs Predicted', size=15)
plot.ylabel('Percentage Score', size=10)
plot.xlabel('Hours Studied', size=10)
plot.show()
print('Mean absolute error: ',mean_absolute_error(y_val,y_pred))
hours = [9.25]
answer = regressor.predict([hours])
print("Score = {}".format(round(answer[0],3)))
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000
# TRAINING COMPLETE
# Mean absolute error:  4.130879918502486
# Score = 93.893
